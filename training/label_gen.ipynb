# %%
# !pip install datasets

# !pip install transformers

# !pip install accelerate -U
# !pip install transformers[torch]
# !pip install torch -U
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.2/521.2 kB 3.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 16.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 19.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.7/265.7 kB 3.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.2/670.2 MB 1.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 37.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 45.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 41.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 3.5 MB/s eta 0:00:00
# ...

# %%
from datasets import Dataset, DatasetDict
import pandas as pd
from huggingface_hub import notebook_login
from datasets import load_dataset
from transformers import AutoTokenizer

# %%
notebook_login()

# %%
dataset = load_dataset('davidgaofc/techdebt_label')
# Out:
# ...
# Generating test split:   0%|          | 0/2199 [00:00<?, ? examples/s]

# %%
tokenizer = AutoTokenizer.from_pretrained("davidgaofc/TechDebtLabeler")

def preprocess_function(examples):
    input_encodings = tokenizer(examples["Message"], truncation=True, padding="max_length")
    target_encodings = tokenizer(examples['Diff'], truncation=True, padding="max_length")
    input_encodings["labels"] = target_encodings["input_ids"]
    return input_encodings

tokenized_dataset = dataset.map(preprocess_function, batched=True)
# Out:
# tokenizer_config.json:   0%|          | 0.00/21.0k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/511k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/294k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.37M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/15.5k [00:00<?, ?B/s]
# ...
# Map:   0%|          | 0/2199 [00:00<?, ? examples/s]

# %%
# !pip install transformers -U
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 19.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 53.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.12.1
#     Uninstalling tokenizers-0.12.1:
#       Successfully uninstalled tokenizers-0.12.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.21.1
#     Uninstalling transformers-4.21.1:
#       Successfully uninstalled transformers-4.21.1
# ...

# %%
from transformers import AutoModelForSeq2SeqLM

model = AutoModelForSeq2SeqLM.from_pretrained("davidgaofc/TechDebtLabeler")
# Out:
# config.json:   0%|          | 0.00/1.65k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/242M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/163 [00:00<?, ?B/s]

# %%
# !pip install evaluate
# !pip install rouge_score
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 1.4 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for rouge_score: filename=rouge_score-0.1.2-py3-none-any.whl size=24933 sha256=5b4103b59e37dd9c1c26a8c6acc2f6d61687e5fde353d5f6f53c0822a67a326e
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
# Successfully built rouge_score
# ...

# %%
import evaluate
import numpy as np

metric = evaluate.load("rouge")

def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    decoded_preds = tokenizer.batch_decode(predictions, skip_special_tokens=True)
    labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)
    result = metric.compute(predictions=decoded_preds, references=decoded_labels, use_stemmer=True)
    prediction_lens = [np.count_nonzero(pred != tokenizer.pad_token_id) for pred in predictions]
    result["gen_len"] = np.mean(prediction_lens)
    result = {k: round(v, 4) for k, v in result.items()}
    return result

# %%
from transformers import TrainingArguments, Trainer
from transformers import DataCollatorForSeq2Seq

data_collator = DataCollatorForSeq2Seq(tokenizer, model=model)
# model.gradient_checkpointing_enable()
training_args = TrainingArguments(output_dir="training",
                                  # learning_rate=2e-5, weight_decay=0.01,
    # num_train_epochs=1,
    # per_device_train_batch_size=1,
    per_device_eval_batch_size=16,
    evaluation_strategy="epoch",
    # save_strategy="epoch",
    # gradient_accumulation_steps = 100
)
# temp = tokenized_dataset["test"].select(range(10))

trainer = Trainer(
    model=model,
    args=training_args,
    # train_dataset=tokenized_dataset["train"],
    eval_dataset= tokenized_dataset["test"],
    tokenizer=tokenizer,
    # data_collator=data_collator,
    compute_metrics = compute_metrics,
)

# %%
# %env PYTORCH_CUDA_ALLOC_CONF=max_split_size_mb:128
# Out:
# env: PYTORCH_CUDA_ALLOC_CONF=max_split_size_mb:128

# %%
import torch
torch.cuda.empty_cache()

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='87' max='87' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [87/87 13:30, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# TrainOutput(global_step=87, training_loss=0.009548048863465759, metrics={'train_runtime': 823.9229, 'train_samples_per_second': 10.672, 'train_steps_per_second': 0.106, 'total_flos': 1177473672806400.0, 'train_loss': 0.009548048863465759, 'epoch': 0.99})

# %%
trainer.push_to_hub()
# Out:
# events.out.tfevents.1699843999.ffa5fcec7a72.1319.0:   0%|          | 0.00/5.20k [00:00<?, ?B/s]
# events.out.tfevents.1699844511.ffa5fcec7a72.1319.1:   0%|          | 0.00/5.20k [00:00<?, ?B/s]
# events.out.tfevents.1699844529.ffa5fcec7a72.1319.2:   0%|          | 0.00/5.20k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/242M [00:00<?, ?B/s]
# Upload 14 LFS files:   0%|          | 0/14 [00:00<?, ?it/s]
# events.out.tfevents.1699844540.ffa5fcec7a72.1319.3:   0%|          | 0.00/5.35k [00:00<?, ?B/s]
# events.out.tfevents.1699845374.ffa5fcec7a72.1319.4:   0%|          | 0.00/5.35k [00:00<?, ?B/s]
# events.out.tfevents.1699845706.ffa5fcec7a72.1319.5:   0%|          | 0.00/5.35k [00:00<?, ?B/s]
# events.out.tfevents.1699846054.ffa5fcec7a72.10229.0:   0%|          | 0.00/5.35k [00:00<?, ?B/s]
# events.out.tfevents.1699846153.ffa5fcec7a72.10229.1:   0%|          | 0.00/5.35k [00:00<?, ?B/s]
# ...

# %%
model.save_pretrained("techdebt_model"+"1")
tokenizer.save_pretrained("techdebt_tokenizer"+"1")

# %%
trainer.evaluate()
# Out:
#     <div>
#
#       <progress value='5' max='138' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [  5/138 00:00 < 00:18, 7.20 it/s]
#     </div>
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# <ipython-input-12-f245b31d31e3> in <cell line: 1>()
# ----> 1 trainer.evaluate()
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in evaluate(self, eval_dataset, ignore_keys, metric_key_prefix)
#    3009
#    3010         eval_loop = self.prediction_loop if self.args.use_legacy_prediction_loop else self.evaluation_loop
# -> 3011         output = eval_loop(
#    3012             eval_dataloader,
#    3013             description="Evaluation",
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in evaluation_loop(self, dataloader, description, prediction_loss_only, ignore_keys, metric_key_prefix)
# ...
